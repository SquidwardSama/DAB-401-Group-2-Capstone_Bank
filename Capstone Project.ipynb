# %%
#Loading The Dataset

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

bank = pd.read_csv("bank-additional-full.csv", sep =";")
pd.options.display.max_columns = None
display(bank)
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
#Looking at the top five rows

bank.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 0   may         mon       261         1    999         0  nonexistent
# 1   may         mon       149         1    999         0  nonexistent
# 2   may         mon       226         1    999         0  nonexistent
# 3   may         mon       151         1    999         0  nonexistent
# 4   may         mon       307         1    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
#Looking at unique values

#Unique JObs

unique_Jobs = (bank['job']).unique()

print("Unique Job Types:")


print(unique_Jobs)
# Out:
# Unique Job Types:
# ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown' 'entrepreneur'
#  'student']

# %%
#Unique Contact type

print("Unique Contact Types:")
unique_Contact = (bank['contact']).unique()
print(unique_Contact)
# Out:
# Unique Contact Types:
# ['telephone' 'cellular']

# %%
#Unique Education

print("Unique Education Types:")

unique_Edu = (bank['education']).unique()

print(unique_Edu)
# Out:
# Unique Education Types:
# ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'unknown' 'university.degree' 'illiterate']

# %%
#Unique Housing

print("Unique Housing Types:")
unique_House = (bank['housing']).unique()
print(unique_House)
# Out:
# Unique Housing Types:
# ['no' 'yes' 'unknown']

# %%
#Unique Marital Status

print("Unique Martial Types")
unique_Marital = (bank['marital']).unique()
print(unique_Marital)
# Out:
# Unique Martial Types
# ['married' 'single' 'divorced' 'unknown']

# %%
#Unique Default

print("Unique Default Types:")
unique_Default = (bank['default']).unique()
print(unique_Default)
# Out:
# Unique Default Types:
# ['no' 'unknown' 'yes']

# %%
#Looking at bottom four rows

bank.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  duration  campaign  pdays  previous  \
# 41183  cellular   nov         fri       334         1    999         0
# 41184  cellular   nov         fri       383         1    999         0
# 41185  cellular   nov         fri       189         2    999         0
# 41186  cellular   nov         fri       442         1    999         0
# 41187  cellular   nov         fri       239         3    999         1
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
#Attribute Description

bk2.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m             y
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291      0.112654
# ...

# %%
#Changing Column Name

bank.rename(columns={"nr.employed":"no.employees"})
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
#Correlation matrix of entire dataset

bank.corr().round(2)
# Out:
#                  age  duration  campaign  pdays  previous  emp.var.rate  \
# age             1.00     -0.00      0.00  -0.03      0.02         -0.00
# duration       -0.00      1.00     -0.07  -0.05      0.02         -0.03
# campaign        0.00     -0.07      1.00   0.05     -0.08          0.15
# pdays          -0.03     -0.05      0.05   1.00     -0.59          0.27
# previous        0.02      0.02     -0.08  -0.59      1.00         -0.42
# emp.var.rate   -0.00     -0.03      0.15   0.27     -0.42          1.00
# cons.price.idx  0.00      0.01      0.13   0.08     -0.20          0.78
# cons.conf.idx   0.13     -0.01     -0.01  -0.09     -0.05          0.20
# euribor3m       0.01     -0.03      0.14   0.30     -0.45          0.97
# nr.employed    -0.02     -0.04      0.14   0.37     -0.50          0.91
#
#                 cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# age                       0.00           0.13       0.01        -0.02
# ...

# %%
#Convert Strings to factors

#Changing Marital
bank['marital'] = bank['marital'].astype('category')

#Changing Education
bank['education'] = bank['education'].astype('category')

#Changing Job
bank['job'] = bank['job'].astype('category')


#Changing Default
bank['default'] = bank['default'].astype('category')


#Changing Housing
bank['housing'] = bank['housing'].astype('category')


#Changing Loan
bank['loan'] = bank['loan'].astype('category')


#Changing Contact
bank['contact'] = bank['contact'].astype('category')


#Changing y
bank['y'] = bank['y'].astype('category')


#Changing Poutcome
bank['poutcome'] = bank['poutcome'].astype('category')

#Changing Month
bank['month'] = bank['month'].astype('category')

#Changing Day of Week
bank['day_of_week'] = bank['day_of_week'].astype('category')


#Checking Types

bank.dtypes
# Out:
# age                  int64
# job               category
# marital           category
# education         category
# default           category
# housing           category
# loan              category
# contact           category
# month             category
# day_of_week       category
# duration             int64
# campaign             int64
# pdays                int64
# previous             int64
# poutcome          category
# cons.price.idx     float64
# cons.conf.idx      float64
# euribor3m          float64
# nr.employed        float64
# y                 category
# dtype: object

# %%
#Checking for NULLs

bank.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
corr = bank.corr()
corr.style.background_gradient(cmap='PuOr')
# Out:
# <style  type="text/css" >
# #T_e42a56da_2c55_11ec_8bf7_acde48001122row0_col0,#T_e42a56da_2c55_11ec_8bf7_acde48001122row1_col1,#T_e42a56da_2c55_11ec_8bf7_acde48001122row2_col2,#T_e42a56da_2c55_11ec_8bf7_acde48001122row3_col3,#T_e42a56da_2c55_11ec_8bf7_acde48001122row4_col4,#T_e42a56da_2c55_11ec_8bf7_acde48001122row5_col5,#T_e42a56da_2c55_11ec_8bf7_acde48001122row6_col6,#T_e42a56da_2c55_11ec_8bf7_acde48001122row7_col7,#T_e42a56da_2c55_11ec_8bf7_acde48001122row8_col8{
#             background-color:  #2d004b;
#             color:  #f1f1f1;
#         }#T_e42a56da_2c55_11ec_8bf7_acde48001122row0_col1{
#             background-color:  #a04d07;
#             color:  #f1f1f1;
#         }#T_e42a56da_2c55_11ec_8bf7_acde48001122row0_col2,#T_e42a56da_2c55_11ec_8bf7_acde48001122row1_col6{
#             background-color:  #a65107;
#             color:  #f1f1f1;
#         }#T_e42a56da_2c55_11ec_8bf7_acde48001122row0_col3{
#             background-color:  #fdcc8c;
#             color:  #000000;
# ...

# %%
#del bank['emp.var.rate']
#del bank['no.employees']

bk2 = bank.drop(['emp.var.rate'], axis = 1)
bk2 = bank.drop(['nr.employed'], axis = 1)
bk.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 0   may         mon       261         1    999         0  nonexistent
# 1   may         mon       149         1    999         0  nonexistent
# 2   may         mon       226         1    999         0  nonexistent
# 3   may         mon       151         1    999         0  nonexistent
# 4   may         mon       307         1    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m   y
# ...

# %%
corr = bk.corr()
corr.style.background_gradient(cmap='PuOr')
# Out:
# <style  type="text/css" >
# #T_f0fb8eee_2c5d_11ec_8bf7_acde48001122row0_col0,#T_f0fb8eee_2c5d_11ec_8bf7_acde48001122row1_col1,#T_f0fb8eee_2c5d_11ec_8bf7_acde48001122row2_col2,#T_f0fb8eee_2c5d_11ec_8bf7_acde48001122row3_col3,#T_f0fb8eee_2c5d_11ec_8bf7_acde48001122row4_col4,#T_f0fb8eee_2c5d_11ec_8bf7_acde48001122row5_col5,#T_f0fb8eee_2c5d_11ec_8bf7_acde48001122row6_col6,#T_f0fb8eee_2c5d_11ec_8bf7_acde48001122row7_col7,#T_f0fb8eee_2c5d_11ec_8bf7_acde48001122row8_col8{
#             background-color:  #2d004b;
#             color:  #f1f1f1;
#         }#T_f0fb8eee_2c5d_11ec_8bf7_acde48001122row0_col1{
#             background-color:  #a04d07;
#             color:  #f1f1f1;
#         }#T_f0fb8eee_2c5d_11ec_8bf7_acde48001122row0_col2,#T_f0fb8eee_2c5d_11ec_8bf7_acde48001122row1_col7{
#             background-color:  #a65107;
#             color:  #f1f1f1;
#         }#T_f0fb8eee_2c5d_11ec_8bf7_acde48001122row0_col3{
#             background-color:  #fdcc8c;
#             color:  #000000;
# ...

# %%
#comparing variance between "emp.var.rate" and "euribor3m"

import statistics

print("emp.var.rate variance:")

print(round(statistics.variance(bk['emp.var.rate']),2))

print("euribor3m variance :")

print(round(statistics.variance(bk['euribor3m']),2))
# Out:
# emp.var.rate variance:
# 2.47
# euribor3m variance :
# 3.01

# %%
#Delete bk[euribor3m]

bk2 = bank.drop(['euribor3m'], axis = 1)

bk2 = bank.drop(['emp.var.rate'], axis = 1)

bk2 = bank.drop(['nr.employed'], axis = 1)

# %%
#Checking correlation matrix

corr = bk2.corr()
corr.style.background_gradient(cmap='PuOr')
# Out:
# <style  type="text/css" >
# #T_010ea070_2c5c_11ec_8bf7_acde48001122row0_col0,#T_010ea070_2c5c_11ec_8bf7_acde48001122row1_col1,#T_010ea070_2c5c_11ec_8bf7_acde48001122row2_col2,#T_010ea070_2c5c_11ec_8bf7_acde48001122row3_col3,#T_010ea070_2c5c_11ec_8bf7_acde48001122row4_col4,#T_010ea070_2c5c_11ec_8bf7_acde48001122row5_col5,#T_010ea070_2c5c_11ec_8bf7_acde48001122row6_col6,#T_010ea070_2c5c_11ec_8bf7_acde48001122row7_col7,#T_010ea070_2c5c_11ec_8bf7_acde48001122row8_col8{
#             background-color:  #2d004b;
#             color:  #f1f1f1;
#         }#T_010ea070_2c5c_11ec_8bf7_acde48001122row0_col1{
#             background-color:  #a04d07;
#             color:  #f1f1f1;
#         }#T_010ea070_2c5c_11ec_8bf7_acde48001122row0_col2,#T_010ea070_2c5c_11ec_8bf7_acde48001122row1_col7{
#             background-color:  #a65107;
#             color:  #f1f1f1;
#         }#T_010ea070_2c5c_11ec_8bf7_acde48001122row0_col3{
#             background-color:  #fdcc8c;
#             color:  #000000;
# ...

# %%
#Encoding Column


bk2.replace(('yes', 'no'), (1, 0), inplace=True)

# %%
#Checking Types
bk2.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# y                   int64
# dtype: object

# %%
print(bk2["y"])
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41183    1
# 41184    0
# 41185    0
# 41186    1
# 41187    0
# Name: y, Length: 41188, dtype: int64

# %%
#Checking Row Count (n)

len(bk2.y)
# Out:
# 41188

# %%
#Checking sum of new encoding

sum(bk2['y'])
# Out:
# 4640

# %%
ConversionRate = round(sum(bk2['y'])/len(bk2.y)*100.0,2)

print(ConversionRate)
# Out:
# 11.27

# %%
#Age Distribution

plt.hist(bk2['age'], bins=[20,25,35,40,45,50,55,60,65,70], edgecolor='black')
plt.xlabel('Customer Age')
plt.ylabel('# of Customers')
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')
